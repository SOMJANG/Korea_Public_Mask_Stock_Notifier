# %%
import requests
import json
from tqdm import tqdm
import pandas as pd

# %%
def getNearMaskStoreInfoByGeo(lat, lng, dist):
    url ="https://8oi9s0nnth.apigw.ntruss.com/corona19-masks/v1/storesByGeo/json?lat=" + str(lat) + "&lng=" + str(lng) + "&m=" + str(dist)
    
    req = requests.get(url)
    
    json_data = req.json()
    store_data = json_data['stores']
    
    addrs = []
    codes = []
    latitudes = []
    longitudes = []
    names = []
    types = []
    created_ats = []
    remain_stats = []
    stock_ats = []
    
    for i in tqdm(range(len(store_data))):
        addrs.append(store_data[i]['addr'])
        codes.append(store_data[i]['code'])
        latitudes.append(store_data[i]['lat'])
        longitudes.append(store_data[i]['lng'])
        names.append(store_data[i]['name'])
        types.append(store_data[i]['type'])
        try:
            created_ats.append(store_data[i]['created_at'])
        except:
            created_ats.append("no_data")
        try:
            remain_stats.append(store_data[i]['remain_stat'])
        except:
            remain_stats.append("no_data")
        try:
            stock_ats.append(store_data[i]['stock_at'])
        except:
            stock_ats.append("no_data")
    
    mask_store_info_df = pd.DataFrame({"addr":addrs, "code":codes, "latitude":latitudes, "longitude":longitudes, "name":names, "type":types, "created_at":created_ats, "remain_stat":remain_stats, "stock_at":stock_ats})
    
    return mask_store_info_df

# %%
mask_store_info_by_geo = getNearMaskStoreInfoByGeo(lat, lng, m)
mask_store_info_by_geo
# Out:
# 100%|██████████| 41/41 [00:00<00:00, 66115.52it/s]
#                                             addr      code   latitude  \
# 0                서울특별시 동작구 노량진로8길 3 (노량진동, 경성빌딩)  11884533  37.512927
# 1                 서울특별시 동작구 노량진로 110 113호 (노량진동)  11898615  37.513209
# 2                  서울특별시 동작구 노량진로 124  1층 (노량진동)  12870013  37.513275
# 3               서울특별시 동작구 장승배기로 168 B001호 (노량진동)  12853127  37.512614
# 4         서울특별시 동작구 노들로 674 노량진수산물도매시장 2층 (노량진동)  11867256  37.514869
# 5                 서울특별시 동작구 노량진로 152 . 1층 (노량진동)  12864188  37.513450
# 6                 서울특별시 동작구 노량진로 162 . 1층 (노량진동)  12819212  37.513404
# 7                        서울특별시 동작구 만양로 86 (노량진동)  11894725  37.511205
# 8              서울특별시 동작구 만양로 112 1층 (노량진동, 서원빌딩)  12834670  37.513334
# 9                   서울특별시 동작구 노량진로 166 1층 (노량진동)  11886731  37.513353
# 10                     서울특별시 동작구 노량진로 155 (노량진동)  11894865  37.513940
# 11          서울특별시 영등포구 63로 36 (여의도동,리버타워빌딩 103호)  11833785  37.519454
# 12            서울특별시 영등포구 63로 45 (여의도동, 여의도시범아파트)  11867493  37.520732
# 13  서울특별시 영등포구 63로 45 7동 1층 19호 (여의도동, 여의도시범아파트)  12866580  37.520732
# 14             서울특별시 동작구 매봉로 178 B02호 (본동, 마본빌딩)  12804843  37.512210
# 15                       서울특별시 동작구 노량진로 234 (본동)  11874538  37.512482
# 16                 서울특별시 동작구 상도로 181 (상도동, 효성약국)  11823755  37.504963
# 17                    서울특별시 동작구 상도로15길 143 (상도동)  11823186  37.505113
# 18                   서울특별시 동작구 장승배기로10길 43 (상도동)  11885882  37.504660
# 19                       서울특별시 동작구 상도로 202 (상도동)  12825018  37.504968
# 20                       서울특별시 동작구 상도로 206 (상도동)  12835625  37.505009
# 21                         서울특별시 동작구 만양로 5 (상도동)  12850942  37.505390
# 22              서울특별시 동작구 장승배기로 107 1층 2호 (노량진동)  12803600  37.507240
# 23                    서울특별시 동작구 장승배기로 119 (노량진동)  11824280  37.508269
# 24                    서울특별시 동작구 장승배기로 110 (노량진동)  12843393  37.507353
# 25                 서울특별시 동작구 장승배기로 110-1, (노량진동)  12846104  37.507440
# 26                   서울특별시 동작구 장승배기로20길 2 (노량진동)  12856878  37.508178
# 27                    서울특별시 동작구 노량진로6길 62 (노량진동)  11824328  37.510384
# 28                 서울특별시 동작구 장승배기로 139-1, (노량진동)  11824310  37.510076
# 29        서울특별시 동작구 만양로 19 1층 (노량진동, 신동아리버파크아파트)  12854336  37.507797
# 30    서울특별시 동작구 만양로 84 2층 208호 (노량진동, 삼익주상복합아파트)  11840838  37.510921
# 31    서울특별시 동작구 만양로 84 102,103호 (노량진동, 삼익주상복합상가)  12803197  37.510921
# 32          서울특별시 동작구 만양로 26 215호 (상도동, 건영아파트상가)  11804408  37.507763
# 33          서울특별시 동작구 등용로 115 101호 (대방동, 엘리시아빌딩)  11823259  37.511462
# 34    서울특별시 동작구 등용로 127 103동 203호 (대방동, 현대아파트상가)  11855738  37.512936
# 35                 서울특별시 동작구 노량진로6길 26 1층 (노량진동)  11824344  37.511951
# 36                    서울특별시 동작구 등용로14길 65 (노량진동)  11840633  37.512520
# 37                      서울특별시 동작구 노량진로 90 (노량진동)  11885769  37.513059
# 38                서울특별시 영등포구 국제금융로 108-6, (여의도동)  11867434  37.518342
# 39          서울특별시 영등포구 국제금융로 112 1층 (여의도동, 상아빌딩)  12857521  37.518382
# 40           서울특별시 영등포구 국제금융로 108 (여의도동,은하빌딩 1층)  11818042  37.518750
#
#      longitude       name type           created_at remain_stat  \
# 0   126.936494       은성약국   01  2020/03/15 13:10:00        some
# 1   126.938056      새중앙약국   01  2020/03/15 13:10:00       break
# 2   126.939636        설약국   01                 None        None
# 3   126.940553      꿈꾸는약국   01  2020/03/15 13:10:00       empty
# 4   126.936843       수산약국   01  2020/03/15 13:10:00       empty
# 5   126.942766    메디팜엔비약국   01  2020/03/15 13:10:00       empty
# 6   126.943961        김약국   01  2020/03/15 13:10:00       break
# 7   126.944616       찬솔약국   01  2020/03/15 13:10:00       empty
# 8   126.944420       이도약국   01  2020/03/15 13:10:00         few
# 9   126.944779       노들약국   01  2020/03/15 13:10:00      plenty
# 10  126.943209       우리약국   01  2020/03/15 13:10:00      plenty
# 11  126.938606       타워약국   01  2020/03/15 13:10:00       empty
# 12  126.936972    여의도성모약국   01  2020/03/15 13:10:00       break
# 13  126.936972    여의도대학약국   01  2020/03/15 13:10:00       empty
# 14  126.952183       금강약국   01  2020/03/15 13:10:00       empty
# 15  126.951937    노량진종로약국   01  2020/03/15 13:10:00       empty
# 16  126.938837       효성약국   01  2020/03/15 13:10:00       empty
# 17  126.938786        성약국   01  2020/03/15 13:10:00         few
# 18  126.941339       보건약국   01  2020/03/15 13:10:00      plenty
# 19  126.941069    건강온누리약국   01  2020/03/15 13:10:00      plenty
# 20  126.941502      세계로약국   01  2020/03/15 13:10:00        some
# 21  126.946552       건강약국   01  2020/03/15 13:10:00       break
# 22  126.939720      엄마랑약국   01  2020/03/15 13:10:00       empty
# 23  126.939885   온누리송학대약국   01  2020/03/15 13:10:00       empty
# 24  126.940165      맑은샘약국   01  2020/03/15 13:10:00       empty
# 25  126.940183      스마일약국   01  2020/03/15 13:10:00      plenty
# 26  126.940409       다은약국   01  2020/03/15 13:10:00       empty
# 27  126.936075       진원약국   01  2020/03/15 13:10:00       empty
# 28  126.939982       신안약국   01  2020/03/15 13:10:00         few
# 29  126.944764      정다운약국   01  2020/03/15 13:10:00       break
# 30  126.945036       아임약국   01  2020/03/15 13:10:00       empty
# 31  126.945036       인화약국   01  2020/03/15 13:10:00       empty
# 32  126.949985       대영약국   01  2020/03/15 13:10:00       empty
# 33  126.931756     가족건강약국   01  2020/03/15 13:10:00      plenty
# 34  126.930671       대방약국   01  2020/03/15 13:10:00       empty
# 35  126.935625       화생약국   01  2020/03/15 13:10:00       empty
# 36  126.935146       유성약국   01  2020/03/15 13:10:00       empty
# 37  126.935732     행복드림약국   01                 None        None
# 38  126.932948       우당약국   01  2020/03/15 13:10:00         few
# 39  126.933901       정문약국   01  2020/03/15 13:10:00       break
# 40  126.933548  건강한세상대한약국   01  2020/03/15 13:10:00       empty
#
#                stock_at
# 0   2020/03/15 10:00:00
# 1   2020/03/14 11:06:00
# 2                  None
# 3   2020/03/13 12:54:00
# 4   2020/03/15 10:22:00
# 5   2020/03/14 11:54:00
# 6   2020/03/15 10:58:00
# 7   2020/03/15 08:53:00
# 8   2020/03/15 10:07:00
# 9   2020/03/15 10:54:00
# 10  2020/03/15 11:23:00
# 11  2020/03/14 11:20:00
# 12  2020/03/14 11:31:00
# 13  2020/03/14 12:17:00
# 14  2020/03/14 08:17:00
# 15  2020/03/15 09:47:00
# 16  2020/03/14 10:06:00
# 17  2020/03/15 09:13:00
# 18  2020/03/15 12:43:00
# 19  2020/03/15 10:55:00
# 20  2020/03/15 12:28:00
# 21  2020/03/14 10:01:00
# 22  2020/03/14 09:16:00
# 23  2020/03/14 08:57:00
# 24  2020/03/14 12:59:00
# 25  2020/03/15 12:53:00
# 26  2020/03/14 11:24:00
# 27  2020/03/14 11:25:00
# 28  2020/03/14 12:52:00
# 29  2020/03/14 11:40:00
# 30  2020/03/14 13:45:00
# 31  2020/03/15 10:06:00
# 32  2020/03/15 09:03:00
# 33  2020/03/15 12:57:00
# 34  2020/03/15 09:39:00
# 35  2020/03/14 11:33:00
# 36  2020/03/14 12:49:00
# 37                 None
# 38  2020/03/15 10:31:00
# 39  2020/03/14 11:24:00
# 40  2020/03/14 11:33:00

# %%
def getNoneEmptyStockStore(mask_store_info_by_geo):
    data_df = mask_store_info_by_geo.loc[:, ['name', 'addr', 'remain_stat', 'stock_at', 'created_at']]
    data_df_nan = data_df.dropna()
    data_df_nan = data_df_nan[data_df_nan['remain_stat'] != 'break']
    data_df_nan = data_df_nan[data_df_nan['remain_stat'] != 'empty']
    data_df_nan = data_df_nan[data_df_nan['remain_stat'] != 'no_data']
    new_index = []
    for i in range(len(data_df_nan['name'])):
        new_index.append(i)
    data_df_nan.index = new_index
    
    return data_df_nan

# %%
mask_stock_info_df = getNoneEmptyStockStore(mask_store_info_by_geo)

# %%
def makeMaskStockMessage(mask_stock_info_df):
    
    remain_stat_kor = {'plenty':'100개 이상', 'some':'30개 이상', 'few':'2개이상 30개 미만'}
    
    text = ""
    if len(mask_stock_info_df) == 0:
        text = "주변 1km 반경 내의 공적판매처의 마스크 재고가 모두 소진되었습니다"
    else:
        name_list = list(mask_stock_info_df['name'])
        addr_list = list(mask_stock_info_df['addr'])
        remain_list = list(mask_stock_info_df['remain_stat'])
        stock_at_list = list(mask_stock_info_df['stock_at'])
        
        for i in range(len(mask_stock_info_df['name'])):
            name = name_list[i]
            addr = addr_list[i]
            remain_stat = remain_list[i]
            stock_at = stock_at_list[i]
            
            text = text + "판매처명 : " + name + "\n" + "주소 : " + addr + "%0A" + "재고상태 : " + remain_stat_kor[remain_stat] + "\n" + "재고 갱신 시간 : " + stock_at + "\n" + "\n"
            
    return text

# %%
makeMaskStockMessage(mask_stock_info_df)
# Out:
# '판매처명 : 은성약국\n주소 : 서울특별시 동작구 노량진로8길 3 (노량진동, 경성빌딩)%0A재고상태 : 30개 이상\n재고 갱신 시간 : 2020/03/15 10:00:00\n\n판매처명 : 이도약국\n주소 : 서울특별시 동작구 만양로 112 1층 (노량진동, 서원빌딩)%0A재고상태 : 2개이상 30개 미만\n재고 갱신 시간 : 2020/03/15 10:07:00\n\n판매처명 : 노들약국\n주소 : 서울특별시 동작구 노량진로 166 1층 (노량진동)%0A재고상태 : 100개 이상\n재고 갱신 시간 : 2020/03/15 10:54:00\n\n판매처명 : 우리약국\n주소 : 서울특별시 동작구 노량진로 155 (노량진동)%0A재고상태 : 100개 이상\n재고 갱신 시간 : 2020/03/15 11:23:00\n\n판매처명 : 성약국\n주소 : 서울특별시 동작구 상도로15길 143 (상도동)%0A재고상태 : 2개이상 30개 미만\n재고 갱신 시간 : 2020/03/15 09:13:00\n\n판매처명 : 보건약국\n주소 : 서울특별시 동작구 장승배기로10길 43 (상도동)%0A재고상태 : 100개 이상\n재고 갱신 시간 : 2020/03/15 12:43:00\n\n판매처명 : 건강온누리약국\n주소 : 서울특별시 동작구 상도로 202 (상도동)%0A재고상태 : 100개 이상\n재고 갱신 시간 : 2020/03/15 10:55:00\n\n판매처명 : 세계로약국\n주소 : 서울특별시 동작구 상도로 206 (상도동)%0A재고상태 : 30개 이상\n재고 갱신 시간 : 2020/03/15 12:28:00\n\n판매처명 : 스마일약국\n주소 : 서울특별시 동작구 장승배기로 110-1, (노량진동)%0A재고상태 : 100개 이상\n재고 갱신 시간 : 2020/03/15 12:53:00\n\n판매처명 : 신안약국\n주소 : 서울특별시 동작구 장승배기로 139-1, (노량진동)%0A재고상태 : 2개이상 30개 미만\n재고 갱신 시간 : 2020/03/14 12:52:00\n\n판매처명 : 가족건강약국\n주소 : 서울특별시 동작구 등용로 115 101호 (대방동, 엘리시아빌딩)%0A재고상태 : 100개 이상\n재고 갱신 시간 : 2020/03/15 12:57:00\n\n판매처명 : 우당약국\n주소 : 서울특별시 영등포구 국제금융로 108-6, (여의도동)%0A재고상태 : 2개이상 30개 미만\n재고 갱신 시간 : 2020/03/15 10:31:00\n\n'

# %%
def makeSendMessage(lat, lng, m):
    mask_store_info_by_geo = getNearMaskStoreInfoByGeo(lat, lng, m)
    mask_stock_info_df = getNoneEmptyStockStore(mask_store_info_by_geo)
    sendMessage = makeMaskStockMessage(mask_stock_info_df)
    return sendMessage

# %%
lat = 37.513489
lng = 126.941986
m = 1000

makeSendMessage(lat, lng, m)
# Out:
# 100%|██████████| 41/41 [00:00<00:00, 73868.76it/s]
# '판매처명 : 은성약국\n주소 : 서울특별시 동작구 노량진로8길 3 (노량진동, 경성빌딩)%0A재고상태 : 30개 이상\n재고 갱신 시간 : 2020/03/15 10:00:00\n\n판매처명 : 노들약국\n주소 : 서울특별시 동작구 노량진로 166 1층 (노량진동)%0A재고상태 : 100개 이상\n재고 갱신 시간 : 2020/03/15 10:54:00\n\n판매처명 : 우리약국\n주소 : 서울특별시 동작구 노량진로 155 (노량진동)%0A재고상태 : 100개 이상\n재고 갱신 시간 : 2020/03/15 11:23:00\n\n판매처명 : 성약국\n주소 : 서울특별시 동작구 상도로15길 143 (상도동)%0A재고상태 : 2개이상 30개 미만\n재고 갱신 시간 : 2020/03/15 09:13:00\n\n판매처명 : 보건약국\n주소 : 서울특별시 동작구 장승배기로10길 43 (상도동)%0A재고상태 : 100개 이상\n재고 갱신 시간 : 2020/03/15 12:43:00\n\n판매처명 : 건강온누리약국\n주소 : 서울특별시 동작구 상도로 202 (상도동)%0A재고상태 : 100개 이상\n재고 갱신 시간 : 2020/03/15 10:55:00\n\n판매처명 : 세계로약국\n주소 : 서울특별시 동작구 상도로 206 (상도동)%0A재고상태 : 30개 이상\n재고 갱신 시간 : 2020/03/15 12:28:00\n\n판매처명 : 스마일약국\n주소 : 서울특별시 동작구 장승배기로 110-1, (노량진동)%0A재고상태 : 100개 이상\n재고 갱신 시간 : 2020/03/15 12:53:00\n\n판매처명 : 신안약국\n주소 : 서울특별시 동작구 장승배기로 139-1, (노량진동)%0A재고상태 : 2개이상 30개 미만\n재고 갱신 시간 : 2020/03/14 12:52:00\n\n판매처명 : 가족건강약국\n주소 : 서울특별시 동작구 등용로 115 101호 (대방동, 엘리시아빌딩)%0A재고상태 : 30개 이상\n재고 갱신 시간 : 2020/03/15 12:57:00\n\n판매처명 : 우당약국\n주소 : 서울특별시 영등포구 국제금융로 108-6, (여의도동)%0A재고상태 : 2개이상 30개 미만\n재고 갱신 시간 : 2020/03/15 10:31:00\n\n'
